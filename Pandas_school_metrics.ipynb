# %%
import pandas as pd
import numpy as np

# %%
school_data_file = "Resources/schools_complete.csv"
student_data_file = "Resources/students_complete.csv"

school_data = pd.read_csv(school_data_file)
student_data = pd.read_csv(student_data_file)
                          
school_data_set = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_set
# Out:
#        Student ID         student_name gender grade         school_name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %%
renamed = school_data_set.rename(columns = {"student_name": "Student Name", "gender": "Gender", "grade": "Grade",
                                           "school_name": "School Name", "reading_score": "Reading Score",
                                           "math_score": "Math Score", "type1": "Type", "size": "Size", "budget":
                                           "Budget"})

renamed
# Out:
#        Student ID         Student Name Gender Grade         School Name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %%
# look for missing values
school_data_set.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# School ID        39170
# type1            39170
# size             39170
# budget           39170
# dtype: int64

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
#no_null_crime_df["Offense Type"].value_counts()
# Combining similar offenses together
#no_null_crime_df["Offense Type"] = no_null_crime_df["Offense Type"].replace(
    #{"Commercial Sex Acts": "Prostitution", "Assisting or Promoting Prostitution": "Prostitution"})
#no_null_crime_df

# %%
#Table of total schools, total students, total budget, average math score, average reading score,
# % Passing Math, % Passing Reading, Overall passing rate (average of math and reading)

district_total = school_data_set[["school_name", "student_name", "budget", "reading_score", "math_score"]]
district_total.head()

#I need to tell it count schools, count students, sum budget, average math, average reading,
# figure out what qualifies as passing for percentages for math and reading, sum then average of math and reading
# Out:
#          school_name       student_name   budget  reading_score  math_score
# 0  Huang High School       Paul Bradley  1910635             66          79
# 1  Huang High School       Victor Smith  1910635             94          61
# 2  Huang High School    Kevin Rodriguez  1910635             90          60
# 3  Huang High School  Dr. Richard Scott  1910635             67          58
# 4  Huang High School         Bonnie Ray  1910635             97          84

# %%
#Total Schools
school_count = len(school_data_set["school_name"].unique())

#Total Students
student_count = len(school_data_set["student_name"].unique())

#Total Budget
budget_sum = school_data_set["budget"].sum()

#Average Reading
avg_reading = school_data_set["reading_score"].mean()

#Average Math
avg_math = school_data_set["math_score"].mean()

#Sum of Reading for below
sum_reading = school_data_set["reading_score"].sum()

#Sum of Math for below
sum_math = school_data_set["math_score"].sum()

#70 or higher, percent of those who passed reading
#my guess is tell it to sum scores of 70 or higher, divide by total/sum, times by 100
pass_read_if = (school_data_set['reading_score']>= 70)
pass_reading_sum = pass_read_if.sum()
pass_reading = (pass_reading_sum / sum_reading) * 100

#70 or higher, percent of those who passed math
pass_math_if = (school_data_set["math_score"] >= 70)
pass_math_sum = pass_math_if.sum()
pass_math = (pass_math_sum / sum_math) * 100

# percent of overall passing rate
#sum then find average of those who passed reading and math, divide by total sum of total sum of each, times by 100
overall_pass = (pass_math + pass_reading) / 2
#Summary DataFrame
district_summary_table = pd.DataFrame({"Total Schools": [school_count], "Total Students": [student_count], "Total Budget":
                                      [budget_sum], "Average Math Score": [avg_math], "Average Reading Score": [avg_reading],
                                      "% Passing Math": [pass_math], "% Passing Reading": [pass_reading],
                                      "% Overall Passing Rate": [overall_pass]})
district_summary_table
#df['total'] = df[['A','B']].sum(axis=1).where(df['A'] > 0, 0)
#df

# Calculate the number of unique authors in the DataFrame
#author_count = len(goodreads_df["Authors"].unique())

# Calculate the earliest/latest year a book was published
#earliest_year = goodreads_df["Publication Year"].min()
#latest_year = goodreads_df["Publication Year"].max()

# Calculate the total reviews for the entire dataset
#total_reviews = goodreads_df["One Star Reviews"].sum() + goodreads_df["Two Star Reviews"].sum(
#) + goodreads_df["Three Star Reviews"].sum() + goodreads_df["Four Star Reviews"].sum() + goodreads_df["Five Star Reviews"].sum()

# Place all of the data found into a summary DataFrame
#summary_table = pd.DataFrame({"Total Unique Authors": author_count,
                              #"Earliest Year": [earliest_year],
                              #"Latest Year": [latest_year],
                              #"Total Reviews": [total_reviews]})
#summary_table
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           32715   82932329558           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784        0.949301           1.047969
#
#    % Overall Passing Rate
# 0                0.998635

# %%
school_data_set.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type1', 'size', 'budget'],
#       dtype='object')

# %%
#set index/school type
school_type = school_data.set_index(["school_name"])["type1"]

#total students
per_school = school_data_set.groupby("school_name")
total_students = per_school["Student ID"].count()

#total school budget
school_budget = school_data_set.groupby("school_name")["budget"].sum()

#student budget
student_budget = school_budget / total_students

#average math score
avg_math = school_data_set.groupby("school_name")["math_score"].mean()

#average reading score
avg_reading = school_data_set.groupby("school_name")["reading_score"].mean()

#sum math
sum_math = school_data_set.groupby("school_name")["reading_score"].sum()

#sum reading
sum_reading = school_data_set.groupby("school_name")["reading_score"].sum()

#pass math

pass_score = school_data_set.loc[school_data_set['math_score'] >= 70, :].groupby("school_name")
math_students = pass_score['Student ID'].count()
pass_math = (math_students/total_students)*100

#pass reading
pass_read_score = school_data_set.loc[school_data_set['reading_score'] >= 70, :].groupby("school_name")
read_students = pass_read_score['Student ID'].count()
pass_reading = (read_students/total_students)*100


#overall passing
overall_passing = (pass_math + pass_reading)/2

#school_data_set[school_data_set.index.duplicated()]

#dataframe
school_summary = pd.DataFrame({'School Type': school_type, 'Total Students': total_students,
                              'Total School Budget': school_budget, 'Student Budget': student_budget,
                              'Average Math Score': avg_math, 'Average Reading Score': avg_reading,
                              '% Passing Math': pass_math, '% Passing Reading': pass_reading,
                              'Overall Passing Rate': overall_passing})
school_summary



#By Schools - each schools':

#def function(student_budget):
    #stu = student_budget.school_name.count()
    #budg = student_budget.budget.sum()
    #stu_budg = (stu/budg)
#student_budget = school_data_set.groupby("school_name").apply(function)

#def func(pass_math):
    #math_pass = (pass_math.math_score.sum() >=70)
    #math_total = pass_math.math_score.sum()
    #passing_math = (math_pass/math_total) * 100
#stu_math_pass = school_data_set.groupby("school_name").apply(func)

#def funct(pass_reading):
    #read_pass = (pass_reading.reading_score.sum() >=70)
    #read_total = pass_reading.reading_score.sum()
    #passing_read = (read_pass/read_total) * 100
#stu_read_pass = school_data_set.groupby("school_name").apply(funct)

#def func(group):
    #sum_ = group.qty.sum()
    #es = (group.csv / group.qty).sum()
    #return pd.Series([sum_, es], index=['qty', 'es'])

#trades.groupby('ordrefno').apply(func)

#school_by = school_data_set.groupby("school_name").agg({'student_name': "count",'budget': "sum",
                                                       #'reading_score': "mean", 'math_score': "mean"})
#school_by
#df.groupby('A').agg({'B': ['min', 'max'], 'C': 'sum'})
# Group the data frame by month and item and extract a number of stats from each group
#data.groupby(['month', 'item']).agg({'duration':sum,      # find the sum of the durations for each group
                                     #'network_type': "count", # find the number of network type entries
                                     #'date': 'first'})    # get the first date per group
#school_by = school_data_set.groupby("school_name")
#school_by

#School name 
#School type
#Total Students

#data.groupby('month')['duration'].sum()

#Total School Budget

#Per Student Budget - total budget divide by total student (I think), trying function
#Average Math Score - average function
#Average Reading Score - average function
#% Passing Math - sum of students passing divide by sum of math times 100
#% Passing Reading - sum of students passing divide by sum of reading imes 100
#Overall Passing Rate (Average of the above two)
#summary_school_by = pd.DataFrame({"School Name": [schools_name], "School Type": [school_type]})
#summary_school_by
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976          15549641728
# Cabrera High School       Charter            1858           2009159448
# Figueroa High School     District            2949           5557128039
# Ford High School         District            2739           4831365924
# Griffin High School       Charter            1468           1346890000
# Hernandez High School    District            4635          14007062700
# Holden High School        Charter             427            105933149
# Huang High School        District            2917           5573322295
# Johnson High School      District            4761          14733628650
# Pena High School          Charter             962            563595396
# Rodriguez High School    District            3999          10186904637
# Shelton High School       Charter            1761           1860672600
# ...

# %%
#Top 5 schools with above information

top_schools = school_summary.sort_values("Overall Passing Rate", ascending=False)
top_schools.head()
#freedom_df = happiness_df.sort_values("Freedom", ascending=False)
#freedom_df.head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858           2009159448
# Thomas High School      Charter            1635           1705517550
# Pena High School        Charter             962            563595396
# Griffin High School     Charter            1468           1346890000
# Wilson High School      Charter            2283           3012587442
#
#                      Student Budget  Average Math Score  \
# Cabrera High School       1081356.0           83.061895
# Thomas High School        1043130.0           83.418349
# Pena High School           585858.0           83.839917
# Griffin High School        917500.0           83.351499
# Wilson High School        1319574.0           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
#Worse 5 schools with above information
bottom_schools = school_summary.sort_values("Overall Passing Rate")
bottom_schools.head()
# Out:
#                       School Type  Total Students  Total School Budget  \
# Rodriguez High School    District            3999          10186904637
# Figueroa High School     District            2949           5557128039
# Huang High School        District            2917           5573322295
# Johnson High School      District            4761          14733628650
# Ford High School         District            2739           4831365924
#
#                        Student Budget  Average Math Score  \
# Rodriguez High School       2547363.0           76.842711
# Figueroa High School        1884411.0           76.711767
# Huang High School           1910635.0           76.629414
# Johnson High School         3094650.0           77.072464
# Ford High School            1763916.0           77.102592
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# Figueroa High School               81.158020       65.988471
# ...

# %%
#Math Scores By Grade
#Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#Create a pandas series for each grade. Hint: use a conditional statement.
#Group each series by school
#Combine the series into a dataframe
#Optional: give the displayed data cleaner formatting

#index by school name
#school_by_math = school_data_set.set_index("school_name")
grade_9 = school_data_set[school_data_set["grade"] == "9th"].groupby("school_name").mean()["math_score"]
grade_10 = school_data_set[school_data_set["grade"] == "10th"].groupby("school_name").mean()["math_score"]
grade_11 = school_data_set[school_data_set["grade"] == "11th"].groupby("school_name").mean()["math_score"]
grade_12 = school_data_set[school_data_set["grade"] == "12th"].groupby("school_name").mean()["math_score"]
#grade_12 = school_data_set[school_data_set["grade"] == "12th"].groupby("school_name").groupby["math_score"].mean()

#nine_grade_score =  school_data_complete_renamed_df[school_data_complete_renamed_df["Grade"] == "9th"].groupby("School Name").mean()["Reading Score"]

#avg_math = school_data_set.groupby("school_name")["math_score"].mean()
#avg_math

math_by_grade = pd.DataFrame({'9th': grade_9, '10th': grade_10, '11th': grade_11, '12th': grade_12})
math_by_grade

#pass_score = school_data_set.loc[school_data_set['math_score'] >= 70, :].groupby("school_name")
#math_students = pass_score['Student ID'].count()
#pass_math = (math_students/total_students)*100

#ideas for showing grade

#This will only show in the columns and not make new columns, but it's a start
#vernon_crime_df = no_null_crime_df.loc[no_null_crime_df["Neighborhood"] == "Vernon"]
#vernon_crime_df

#school_grades_math = school_data_set.loc[school_data_set["grade" >= 9]]
#school_grades_math = pd.Series(["grades"], index = ['9', '10', '11', '12']) <== does not work
#school_grades_math


# Set new index to last_name
#df = df_original.set_index("last_name")
#df.head()

#school_name_math = school_data_set.set_index(["school_name", "grade"]).agg({'math_score': "mean"})
#school_name_math

#data.groupby(['month', 'item']).agg({'duration':sum,      # find the sum of the durations for each group
                                     #'network_type': "count", # find the number of network type entries
                                     #'date': 'first'})    # get the first date per group


#example of a function groupby
#def get_letter_type(letter):
   #if letter.lower() in 'aeiou':
    #return 'vowel'
#else:
    #return 'consonant'

#grouped = df.groupby(get_letter_type, axis=1)
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
#Perform the same operations as above for reading scores
grade_9_r = school_data_set[school_data_set["grade"] == "9th"].groupby("school_name").mean()["reading_score"]
grade_10_r = school_data_set[school_data_set["grade"] == "10th"].groupby("school_name").mean()["reading_score"]
grade_11_r = school_data_set[school_data_set["grade"] == "11th"].groupby("school_name").mean()["reading_score"]
grade_12_r = school_data_set[school_data_set["grade"] == "12th"].groupby("school_name").mean()["reading_score"]

read_by_grade = pd.DataFrame({'9th': grade_9_r, '10th': grade_10_r, '11th': grade_11_r, '12th': grade_12_r})
read_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
#Calculating average budget per student
per_school_b = school_data_set.groupby("school_name")
total_students_b = per_school_b["Student ID"].count()
#total school budget
school_budget_b = school_data_set.groupby("school_name")["budget"].mean()
#student budget
student_budget_avg = school_budget_b / total_students_b

student_budget_avg.max()
# Out:
# 655.0

# %%
#Trying to create new column in order to do binning on next problem
#total students
per_school = school_data_set.groupby("school_name")
total_students = per_school["Student ID"].count()

#total school budget
school_budget = school_data_set.groupby("school_name")["budget"].sum()

#student budget
student_budget = school_budget / total_students
school_data_set = school_data_set.assign(budget_student=p.Series(student_budget).values)
school_data_set

# %%
budget_index = school_data_set.set_index(["budget"])

#total students
total_students_b = school_data_set["Student ID"].count()

#total school budget
school_budget_b = school_data_set["budget"].mean()

#student budget
student_budget_avg_b = school_budget_b / total_students_b

#Average Reading
avg_reading_b = school_data_set["reading_score"].mean()

avg_budg_student = pd.DataFrame({"Budget": budget_index, "Spending Ranges Per Student": student_budget_avg_b, "Average Reading": avg_reading_b})
avg_budg_student
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-7cf159d73003> in <module>()
#      13 avg_reading_b = school_data_set["reading_score"].mean()
#      14
# ---> 15 avg_budg_student = pd.DataFrame({"Budget": budget_index, "Spending Ranges Per Student": student_budget_avg_b, "Average Reading": avg_reading_b})
#      16 avg_budg_student
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ...

# %%
#Scores by School spending
#Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#Average Math Score
#Average Reading Score
#% Passing Math
#% Passing Reading
#Overall Passing Rate (Average of the above two)

#budget and size
#budget_avg = school_data_set.groupby("budget").mean()
#Same problem as below since I would need to divide

#Bin
bins = [0, 585, 600, 655]


#Labels for bins
group_labels = ["< $585", "$585-$600", "$600-$655", ">$655"]

#index average spending ranges PER STUDENT
# Maybe make into a function instead???

#total students
total_students_b = school_data_set["Student ID"].count()

#total school budget
school_budget_b = school_data_set["budget"].mean()

#student budget
student_budget_avg_b = school_budget_b / total_students_b

school_data_set["Spending Ranges Per Student"] = pd.cut(['Average Spending'], bins, labels=group_labels)
budget_bin = budget_summary_bin.groupby("Spending Ranges Per Student")

#Average Reading
avg_reading_b = school_data_set["reading_score"].mean()

avg_budg_student = pd.DataFrame({"Spending Ranges Per Student": student_budget_avg_b, "Average Reading": avg_reading_b})

#Average Math
avg_math_b = school_data_set["math_score"].mean()

#Sum of Reading for below
sum_reading_b = school_data_set["reading_score"].sum()

#Sum of Math for below
sum_math_b = school_data_set["math_score"].sum()

#70 or higher, percent of those who passed reading
#my guess is tell it to sum scores of 70 or higher, divide by total/sum, times by 100
pass_read_if_b = (school_data_set['reading_score']>= 70)
pass_reading_sum_b = pass_read_if_b.sum()
pass_reading_b = (pass_reading_sum_b / sum_reading_b) * 100

#70 or higher, percent of those who passed math
pass_math_if_b = (school_data_set["math_score"] >= 70)
pass_math_sum_b = pass_math_if_b.sum()
pass_math_b = (pass_math_sum_b / sum_math_b) * 100

# percent of overall passing rate
#sum then find average of those who passed reading and math, divide by total sum of total sum of each, times by 100
overall_pass_b = (pass_math_b + pass_reading_b) / 2

#school_data_set["Spending Ranges (Per Student)"] = pd.cut(["student_budget_avg_b"], bins, labels=group_labels)
#budget_bin = school_data_set.groupby("Spending Ranges (Per Student)")

#dataframe
budget_summary_bin = pd.DataFrame({'Average Spending': student_budget_avg_b, 'Average Math Score': [avg_math_b], 'Average Reading Score': [avg_reading_b],
                              '% Passing Math': [pass_math_b], '% Passing Reading': [pass_reading_b],
                              'Overall Passing Rate': [overall_pass_b]})
#budget_summary_bin
#budget_summary_bin["Spending Ranges Per Student"] = pd.cut(budget_summary_bin['Average Spending'], bins, labels=group_labels)
#budget_bin = budget_summary_bin.groupby("Spending Ranges Per Student")
#budget_bin

#school_data_set["Spending Ranges (Per Student)"] = pd.cut(["student_budget_avg_b"], bins, labels=group_labels)
#budget_bin = school_data_set.groupby("Spending Ranges (Per Student)")

#budget_summary_bin["Spending Ranges (Per Student)"] = pd.cut(school_data_set["budget"], bins, labels=group_labels)
#budget_summary_bin



#seeing if a grouby bin works


#ted_df["View Group"] = pd.cut(ted_df["views"], bins, labels=group_labels)
#ted_df.head() "View Group" is what would be listed for title if this was not a grouby
#ted_group = ted_df.groupby("View Group")

#grade_9 = school_data_set[school_data_set["grade"] == "9th"].groupby("school_name").mean()["math_score"]

#pass_score = school_data_set.loc[school_data_set['math_score'] >= 70, :].groupby("school_name")
#math_students = pass_score['Student ID'].count()
#pass_math = (math_students/total_students)*100

#school_spending = pd.DataFrame({'Average Math Score': grade_9, 'Average Reading Score': grade_10,
                                #'% Passing Math': grade_11, '% Passing Reading': grade_12,
                               #'Overall Passing Rate'})
#school_spending
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-b46dd80b24a6> in <module>()
#      62                               'Overall Passing Rate': [overall_pass_b]})
#      63 #budget_summary_bin
# ---> 64 budget_summary_bin["Spending Ranges Per Student"] = pd.cut(budget_summary_bin['Average Spending'], bins, labels=group_labels)
#      65 budget_bin = budget_summary_bin.groupby("Spending Ranges Per Student")
#      66 budget_bin
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     232                               include_lowest=include_lowest,
#     233                               dtype=dtype,
# --> 234                               duplicates=duplicates)
#     235
#     236     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# ...

# %%
#Scores by School size
#Perform the same operations as above, based on school size.

# %%
#Scores by school type
#Perform the same operations as above, based on school type

# %%
# The value_counts method counts unique values in a column
count = data_file_pd["Gender"].value_counts()
count

# Calculations can also be performed on Series and added into DataFrames as new columns
thousands_of_dollars = data_file_pd["Amount"]/1000
data_file_pd["Thousands of Dollars"] = thousands_of_dollars

data_file_pd.head()

# Remove unecessary columns from the DataFrame and save the new DataFrame
# Only keep: "isbn", "original_publication_year", "original_title", "authors",
# "ratings_1", "ratings_2", "ratings_3", "ratings_4", "ratings_5"
reduced_df = books_df[["isbn", "original_publication_year", "original_title", "authors",
                       "ratings_1", "ratings_2", "ratings_3", "ratings_4", "ratings_5"]]
reduced_df.head()
